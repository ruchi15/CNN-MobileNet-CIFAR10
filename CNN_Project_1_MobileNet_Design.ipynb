# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchi15/CNN-MobileNet-CIFAR10/blob/master/CNN_Project_1_MobileNet_Design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tenorflow
# select tensorflow 2 in colab
# %tensorflow_version 2.x
import tensorflow as     tf
from   tensorflow import keras

# %%
tf.__version__
# Out:
# '2.2.0-rc2'

# %%
# tensorflow datasets
import tensorflow_datasets as tfds

# %%
# additional libraries
import math
import numpy             as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# data
DATA_NUM_CLASSES        = 10
DATA_CHANNELS           = 3
DATA_ROWS               = 32
DATA_COLS               = 32
DATA_CROP_ROWS          = 28
DATA_CROP_COLS          = 28
DATA_MEAN               = np.array([[[125.30691805, 122.95039414, 113.86538318]]]) # CIFAR10
DATA_STD_DEV            = np.array([[[ 62.99321928,  62.08870764,  66.70489964]]]) # CIFAR10

# %%
# model
MODEL_LEVEL_0_BLOCKS    = 4
MODEL_LEVEL_1_BLOCKS    = 6
MODEL_LEVEL_2_BLOCKS    = 3

# %%
# training
TRAINING_BATCH_SIZE      = 32
TRAINING_SHUFFLE_BUFFER  = 5000
TRAINING_BN_MOMENTUM     = 0.99
TRAINING_BN_EPSILON      = 0.001
TRAINING_LR_MAX          = 0.001
# TRAINING_LR_SCALE        = 0.1
# TRAINING_LR_EPOCHS       = 2
TRAINING_LR_INIT_SCALE   = 0.01
TRAINING_LR_INIT_EPOCHS  = 5
TRAINING_LR_FINAL_SCALE  = 0.01
TRAINING_LR_FINAL_EPOCHS = 55
DEPTH_MULTIPLIER = 1
RESOLUTION_MULTIPLIER = 1

# %%
# training (derived)
TRAINING_NUM_EPOCHS = TRAINING_LR_INIT_EPOCHS + TRAINING_LR_FINAL_EPOCHS
TRAINING_LR_INIT    = TRAINING_LR_MAX*TRAINING_LR_INIT_SCALE
TRAINING_LR_FINAL   = TRAINING_LR_MAX*TRAINING_LR_FINAL_SCALE

# %%
# saving
SAVE_MODEL_PATH = './save/model/'
# !mkdir -p "$SAVE_MODEL_PATH"

# %%
# pre processing for training data
def pre_processing_train(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]
  
    # image is cast to float32, normalized, augmented and random cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_crop(image, size=[DATA_CROP_ROWS, DATA_CROP_COLS, 3])
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# pre processing for testing data
def pre_processing_test(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]

    # image is cast to float32, normalized, augmented and center cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.crop_to_bounding_box(image, (DATA_ROWS - DATA_CROP_ROWS) // 2, (DATA_COLS - DATA_CROP_COLS) // 2, DATA_CROP_ROWS, DATA_CROP_COLS)
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# download data and split into training and testing datasets
dataset_train, info = tfds.load("cifar10", split=tfds.Split.TRAIN, with_info=True)
dataset_test,  info = tfds.load("cifar10", split=tfds.Split.TEST,  with_info=True)
dataset_train_np = tfds.as_numpy(dataset_train)
dataset_test_np = tfds.as_numpy(dataset_test)
# Out:
# Downloading and preparing dataset cifar10/3.0.0 (download: 162.17 MiB, generated: Unknown size, total: 162.17 MiB) to /root/tensorflow_datasets/cifar10/3.0.0...
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Completed...', max=1, style=ProgressStyl…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Size...', max=1, style=ProgressStyle(des…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Extraction completed...', max=1, style=Prog…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteCYE8D1/cifar10-train.tfrecord
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteCYE8D1/cifar10-test.tfrecord
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.0. Subsequent calls will reuse this data.

# %%
# transform training dataset
dataset_train = dataset_train.map(pre_processing_train, num_parallel_calls=4)
dataset_train = dataset_train.shuffle(buffer_size=TRAINING_SHUFFLE_BUFFER)
dataset_train = dataset_train.batch(TRAINING_BATCH_SIZE)
dataset_train = dataset_train.prefetch(buffer_size=1)

# %%
# transform testing dataset
dataset_test = dataset_test.map(pre_processing_test, num_parallel_calls=4)
dataset_test = dataset_test.batch(TRAINING_BATCH_SIZE)
dataset_test = dataset_test.prefetch(buffer_size=1)

# %%
from tensorflow.keras.layers import Input, Activation, Conv2D, Dense, Dropout, BatchNormalization, ReLU, DepthwiseConv2D, GlobalAveragePooling2D, GlobalMaxPooling2D, Add
from tensorflow.keras.models import Model
from keras import regularizers

# define the calculation of each 'inverted Res_Block'
def mobileNet_block(x, filters, stride, depth_multiplier, block_id):
    prefix = 'block_{}_'.format(block_id)

    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, depth_multiplier = depth_multiplier, activation=None, use_bias=False, padding='same', kernel_initializer="he_normal", depthwise_regularizer=regularizers.l2(4e-5), name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=prefix + 'depthwise_BN')(x)
    x = ReLU(6., name=prefix + 'depthwise_relu')(x)

    # Pointwise
    x = Conv2D(filters, kernel_size=1, strides=1, padding='same', use_bias=False, activation=None, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(4e-5), name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=prefix + 'project_BN')(x)
    x = ReLU(6., name=prefix + 'pointwise_relu')(x)

    return x

#Create Build
def create_model(rows, cols, channels, level_0_blocks, level_1_blocks, level_2_blocks, num_classes, lr_initial):
    
    # encoder - input
    model_input = keras.Input(shape=(rows, cols, channels), name='input_image')
    x = model_input

    # model architechture
    x = Conv2D(32, kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(4e-5), name='Conv1')(model_input)

    x = mobileNet_block(x, filters=64, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=0)
    x = mobileNet_block(x, filters=64, stride=2, depth_multiplier=DEPTH_MULTIPLIER, block_id=1)

    x = mobileNet_block(x, filters=128, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=2)

    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=3)
    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=4)

    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=5)

    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=6)
    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=7)
    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=8)
    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=9)
    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=10)

    x = mobileNet_block(x, filters=256, stride=2, depth_multiplier=DEPTH_MULTIPLIER, block_id=11)
    x = mobileNet_block(x, filters=256, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=12)

    # x = mobileNet_block(x, filters=512, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=6)
    # x = mobileNet_block(x, filters=512, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=7)
    # x = mobileNet_block(x, filters=512, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=8)
    # x = mobileNet_block(x, filters=512, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=9)
    # x = mobileNet_block(x, filters=512, stride=1, depth_multiplier=DEPTH_MULTIPLIER, block_id=10)
    
    # x = mobileNet_block(x, filters=1024, stride=2, depth_multiplier=DEPTH_MULTIPLIER, block_id=11)
    # x = mobileNet_block(x, filters=1024, stride=2, depth_multiplier=DEPTH_MULTIPLIER, block_id=12)
    
    # Decoder
    x = GlobalAveragePooling2D(name='global_average_pool')(x)
    x = Dense(DATA_NUM_CLASSES, activation='softmax', use_bias=True, name='Logits')(x)

    # create model of MobileNet (for CIFAR-10)
    model = Model(inputs=model_input, outputs=x, name='mobilenet_cifar10')

    model.compile(optimizer=tf.keras.optimizers.RMSprop(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model
# Out:
# Using TensorFlow backend.

# %%
import os
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, CSVLogger, LearningRateScheduler
from datetime import datetime
model_name      = 'mobilenet-like__' + datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

# build model
# create and compile model
model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, 
                     MODEL_LEVEL_0_BLOCKS, MODEL_LEVEL_1_BLOCKS, MODEL_LEVEL_2_BLOCKS, 
                     DATA_NUM_CLASSES, TRAINING_LR_MAX)
model.summary()
keras.utils.plot_model(model, 'cifar_model.png', show_shapes=True)

def lr_schedule(epoch):
    # staircase
    # lr = TRAINING_LR_MAX*math.pow(TRAINING_LR_SCALE, math.floor(epoch/TRAINING_LR_EPOCHS))
    # linear warmup followed by cosine decay
    if epoch < TRAINING_LR_INIT_EPOCHS:
        lr = (TRAINING_LR_MAX - TRAINING_LR_INIT)*(float(epoch)/TRAINING_LR_INIT_EPOCHS) + TRAINING_LR_INIT
    else:
        lr = (TRAINING_LR_MAX - TRAINING_LR_FINAL)
        #max(0.0, math.cos(((float(epoch) - TRAINING_LR_INIT_EPOCHS)/(TRAINING_LR_FINAL_EPOCHS - 1.0))(math.pi/2.0))) + TRAINING_LR_FINAL
    # debug - learning rate display
    # print(epoch)
    # print(lr)
    return lr

# plot training accuracy and loss curves
def plot_training_curves(history):

    # training and validation data accuracy
    acc     = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # training and validation data loss
    loss     = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()), 1])
    plt.title('Training and Validation Accuracy')

    # plot loss
    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0, 2.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule),
             keras.callbacks.ModelCheckpoint(filepath=SAVE_MODEL_PATH+'model_{epoch}.h5', save_best_only=True, monitor='val_loss', verbose=1)]
#compile & learning model

initial_epoch_num = 0
history = model.fit(x=dataset_train,
                epochs=60,
                verbose=1, 
                callbacks=callbacks, 
                validation_data=dataset_test,
                initial_epoch=initial_epoch_num)

plot_training_curves(history)
# test

test_loss, test_accuracy = model.evaluate(x=dataset_test)
print('Test loss:     ', test_loss)
print('Test accuracy: ', test_accuracy)

# extract a batch from the testing dataset then extract images and labels for this batch

# dataset_display                = dataset_test.take(1)
# it                             = iter(dataset_display)
# display_images, display_labels = next(it)



# # predict pmf and labels for this dataset

# predict_labels_pmf = model.predict(x=dataset_display)

# predict_labels     = np.argmax(predict_labels_pmf, axis=1)

# # for display normalize images to [0, 1]

# display_images = ((display_images*DATA_STD_DEV.reshape((1, 1, 1, 3))) + DATA_MEAN.reshape((1, 1, 1, 3)))/255.0;

# # cycle through the images in the batch

# for image_index in range(predict_labels.size):
#     # display the predicted label, actual label and image
#     print('Predicted label: {0:1d} and actual label: {1:1d}'.format(predict_labels[image_index], display_labels[image_index]))
#     plt.imshow(display_images[image_index, :, :, :])
#     plt.show()


# # save model "INSTANCE"
# f1_name = model_name + '_instance'
# f1_path = os.path.join(log_dir, f1_name) + '.h5'
# model.save(f1_path)

# # save model "WEIGHTs"
# f2_name = model_name + '_weights'
# f2_path = os.path.join(log_dir, f2_name) + '.h5'
# model.save_weights(f2_path)

# # save model "ARCHITECHTURE"
# f3_name = model_name + '_architechture'
# f3_path = os.path.join(log_dir, f3_name) + '.json'
# json_string = model.to_json()
# with open(f3_path, 'w') as f:
#     f.write(json_string)

# # save plot figure
# save_plot_log(log_dir, model_csv_path, index='acc')
# Out:
# Model: "mobilenet_cifar10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 28, 28, 3)]       0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 28, 28, 32)        864
# _________________________________________________________________
# block_0_depthwise (Depthwise (None, 28, 28, 32)        288
# _________________________________________________________________
# block_0_depthwise_BN (BatchN (None, 28, 28, 32)        128
# _________________________________________________________________
# block_0_depthwise_relu (ReLU (None, 28, 28, 32)        0
# _________________________________________________________________
# block_0_project (Conv2D)     (None, 28, 28, 64)        2048
# _________________________________________________________________
# block_0_project_BN (BatchNor (None, 28, 28, 64)        256
# _________________________________________________________________
# block_0_pointwise_relu (ReLU (None, 28, 28, 64)        0
# _________________________________________________________________
# block_1_depthwise (Depthwise (None, 14, 14, 64)        576
# _________________________________________________________________
# block_1_depthwise_BN (BatchN (None, 14, 14, 64)        256
# _________________________________________________________________
# block_1_depthwise_relu (ReLU (None, 14, 14, 64)        0
# _________________________________________________________________
# block_1_project (Conv2D)     (None, 14, 14, 64)        4096
# _________________________________________________________________
# block_1_project_BN (BatchNor (None, 14, 14, 64)        256
# _________________________________________________________________
# block_1_pointwise_relu (ReLU (None, 14, 14, 64)        0
# _________________________________________________________________
# block_2_depthwise (Depthwise (None, 14, 14, 64)        576
# _________________________________________________________________
# block_2_depthwise_BN (BatchN (None, 14, 14, 64)        256
# _________________________________________________________________
# block_2_depthwise_relu (ReLU (None, 14, 14, 64)        0
# _________________________________________________________________
# block_2_project (Conv2D)     (None, 14, 14, 128)       8192
# _________________________________________________________________
# block_2_project_BN (BatchNor (None, 14, 14, 128)       512
# _________________________________________________________________
# block_2_pointwise_relu (ReLU (None, 14, 14, 128)       0
# _________________________________________________________________
# block_3_depthwise (Depthwise (None, 14, 14, 128)       1152
# _________________________________________________________________
# block_3_depthwise_BN (BatchN (None, 14, 14, 128)       512
# _________________________________________________________________
# block_3_depthwise_relu (ReLU (None, 14, 14, 128)       0
# _________________________________________________________________
# block_3_project (Conv2D)     (None, 14, 14, 256)       32768
# _________________________________________________________________
# block_3_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_3_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_4_depthwise (Depthwise (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_4_depthwise_BN (BatchN (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_4_depthwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_4_project (Conv2D)     (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_4_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_4_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_5_depthwise (Depthwise (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_5_depthwise_BN (BatchN (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_5_depthwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_5_project (Conv2D)     (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_5_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_5_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_6_depthwise (Depthwise (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_6_depthwise_BN (BatchN (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_6_depthwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_6_project (Conv2D)     (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_6_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_6_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_7_depthwise (Depthwise (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_7_depthwise_BN (BatchN (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_7_depthwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_7_project (Conv2D)     (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_7_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_7_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_8_depthwise (Depthwise (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_8_depthwise_BN (BatchN (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_8_depthwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_8_project (Conv2D)     (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_8_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_8_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_9_depthwise (Depthwise (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_9_depthwise_BN (BatchN (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_9_depthwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_9_project (Conv2D)     (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_9_project_BN (BatchNor (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_9_pointwise_relu (ReLU (None, 14, 14, 256)       0
# _________________________________________________________________
# block_10_depthwise (Depthwis (None, 14, 14, 256)       2304
# _________________________________________________________________
# block_10_depthwise_BN (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_10_depthwise_relu (ReL (None, 14, 14, 256)       0
# _________________________________________________________________
# block_10_project (Conv2D)    (None, 14, 14, 256)       65536
# _________________________________________________________________
# block_10_project_BN (BatchNo (None, 14, 14, 256)       1024
# _________________________________________________________________
# block_10_pointwise_relu (ReL (None, 14, 14, 256)       0
# _________________________________________________________________
# block_11_depthwise (Depthwis (None, 7, 7, 256)         2304
# _________________________________________________________________
# block_11_depthwise_BN (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# block_11_depthwise_relu (ReL (None, 7, 7, 256)         0
# _________________________________________________________________
# block_11_project (Conv2D)    (None, 7, 7, 256)         65536
# _________________________________________________________________
# block_11_project_BN (BatchNo (None, 7, 7, 256)         1024
# _________________________________________________________________
# block_11_pointwise_relu (ReL (None, 7, 7, 256)         0
# _________________________________________________________________
# block_12_depthwise (Depthwis (None, 7, 7, 256)         2304
# _________________________________________________________________
# block_12_depthwise_BN (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# block_12_depthwise_relu (ReL (None, 7, 7, 256)         0
# _________________________________________________________________
# block_12_project (Conv2D)    (None, 7, 7, 256)         65536
# _________________________________________________________________
# block_12_project_BN (BatchNo (None, 7, 7, 256)         1024
# _________________________________________________________________
# block_12_pointwise_relu (ReL (None, 7, 7, 256)         0
# _________________________________________________________________
# global_average_pool (GlobalA (None, 256)               0
# _________________________________________________________________
# Logits (Dense)               (None, 10)                2570
# =================================================================
# Total params: 685,322
# Trainable params: 674,506
# Non-trainable params: 10,816
# _________________________________________________________________
# Epoch 1/60
# 1563/1563 [==============================] - ETA: 0s - loss: 2.5194 - accuracy: 0.1289
# Epoch 00001: val_loss improved from inf to 2.56227, saving model to ./save/model/model_1.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.5194 - accuracy: 0.1289 - val_loss: 2.5623 - val_accuracy: 0.1000 - lr: 1.0000e-05
# Epoch 2/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.0080 - accuracy: 0.3348
# Epoch 00002: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 48s 31ms/step - loss: 2.0077 - accuracy: 0.3349 - val_loss: 3.2738 - val_accuracy: 0.1000 - lr: 2.0800e-04
# Epoch 3/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.6602 - accuracy: 0.4773
# Epoch 00003: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.6598 - accuracy: 0.4774 - val_loss: 4.4834 - val_accuracy: 0.1011 - lr: 4.0600e-04
# Epoch 4/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.4837 - accuracy: 0.5490
# Epoch 00004: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.4834 - accuracy: 0.5491 - val_loss: 2.9190 - val_accuracy: 0.3270 - lr: 6.0400e-04
# Epoch 5/60
# 1563/1563 [==============================] - ETA: 0s - loss: 1.3001 - accuracy: 0.6184
# Epoch 00005: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.3001 - accuracy: 0.6184 - val_loss: 4.6448 - val_accuracy: 0.3056 - lr: 8.0200e-04
# Epoch 6/60
# 1563/1563 [==============================] - ETA: 0s - loss: 1.1291 - accuracy: 0.6842
# Epoch 00006: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.1291 - accuracy: 0.6842 - val_loss: 4.6602 - val_accuracy: 0.4137 - lr: 9.9000e-04
# Epoch 7/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.9847 - accuracy: 0.7368
# Epoch 00007: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.9848 - accuracy: 0.7369 - val_loss: 4.0690 - val_accuracy: 0.4129 - lr: 9.9000e-04
# Epoch 8/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8958 - accuracy: 0.7672
# Epoch 00008: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.8958 - accuracy: 0.7672 - val_loss: 5.5153 - val_accuracy: 0.3351 - lr: 9.9000e-04
# Epoch 9/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.8299 - accuracy: 0.7879
# Epoch 00009: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.8301 - accuracy: 0.7878 - val_loss: 2.7389 - val_accuracy: 0.5447 - lr: 9.9000e-04
# Epoch 10/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7817 - accuracy: 0.8065
# Epoch 00010: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.7815 - accuracy: 0.8066 - val_loss: 3.0435 - val_accuracy: 0.5449 - lr: 9.9000e-04
# Epoch 11/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7442 - accuracy: 0.8176
# Epoch 00011: val_loss did not improve from 2.56227
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.7445 - accuracy: 0.8175 - val_loss: 3.1887 - val_accuracy: 0.5311 - lr: 9.9000e-04
# Epoch 12/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7119 - accuracy: 0.8294
# Epoch 00012: val_loss improved from 2.56227 to 1.46122, saving model to ./save/model/model_12.h5
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.7119 - accuracy: 0.8294 - val_loss: 1.4612 - val_accuracy: 0.6923 - lr: 9.9000e-04
# Epoch 13/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6872 - accuracy: 0.8391
# Epoch 00013: val_loss did not improve from 1.46122
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.6870 - accuracy: 0.8391 - val_loss: 1.6661 - val_accuracy: 0.6862 - lr: 9.9000e-04
# Epoch 14/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6621 - accuracy: 0.8461
# Epoch 00014: val_loss improved from 1.46122 to 1.10062, saving model to ./save/model/model_14.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.6620 - accuracy: 0.8462 - val_loss: 1.1006 - val_accuracy: 0.7542 - lr: 9.9000e-04
# Epoch 15/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.8538
# Epoch 00015: val_loss improved from 1.10062 to 1.04134, saving model to ./save/model/model_15.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.6440 - accuracy: 0.8538 - val_loss: 1.0413 - val_accuracy: 0.7630 - lr: 9.9000e-04
# Epoch 16/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.8581
# Epoch 00016: val_loss did not improve from 1.04134
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6311 - accuracy: 0.8581 - val_loss: 1.2481 - val_accuracy: 0.7179 - lr: 9.9000e-04
# Epoch 17/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6138 - accuracy: 0.8653
# Epoch 00017: val_loss did not improve from 1.04134
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6142 - accuracy: 0.8652 - val_loss: 1.6112 - val_accuracy: 0.6760 - lr: 9.9000e-04
# Epoch 18/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6077 - accuracy: 0.8672
# Epoch 00018: val_loss did not improve from 1.04134
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6075 - accuracy: 0.8673 - val_loss: 1.3193 - val_accuracy: 0.7272 - lr: 9.9000e-04
# Epoch 19/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5923 - accuracy: 0.8717
# Epoch 00019: val_loss did not improve from 1.04134
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5927 - accuracy: 0.8717 - val_loss: 1.2375 - val_accuracy: 0.7485 - lr: 9.9000e-04
# Epoch 20/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5836 - accuracy: 0.8761
# Epoch 00020: val_loss improved from 1.04134 to 1.03967, saving model to ./save/model/model_20.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5835 - accuracy: 0.8761 - val_loss: 1.0397 - val_accuracy: 0.7746 - lr: 9.9000e-04
# Epoch 21/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5750 - accuracy: 0.8785
# Epoch 00021: val_loss did not improve from 1.03967
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5751 - accuracy: 0.8785 - val_loss: 1.0906 - val_accuracy: 0.7493 - lr: 9.9000e-04
# Epoch 22/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5607 - accuracy: 0.8834
# Epoch 00022: val_loss did not improve from 1.03967
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5609 - accuracy: 0.8833 - val_loss: 1.2058 - val_accuracy: 0.7498 - lr: 9.9000e-04
# Epoch 23/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5584 - accuracy: 0.8844
# Epoch 00023: val_loss did not improve from 1.03967
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5585 - accuracy: 0.8844 - val_loss: 1.0795 - val_accuracy: 0.7832 - lr: 9.9000e-04
# Epoch 24/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.8887
# Epoch 00024: val_loss improved from 1.03967 to 0.96608, saving model to ./save/model/model_24.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5466 - accuracy: 0.8887 - val_loss: 0.9661 - val_accuracy: 0.7786 - lr: 9.9000e-04
# Epoch 25/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5451 - accuracy: 0.8908
# Epoch 00025: val_loss improved from 0.96608 to 0.86310, saving model to ./save/model/model_25.h5
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5451 - accuracy: 0.8907 - val_loss: 0.8631 - val_accuracy: 0.8011 - lr: 9.9000e-04
# Epoch 26/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.8927
# Epoch 00026: val_loss improved from 0.86310 to 0.82997, saving model to ./save/model/model_26.h5
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5381 - accuracy: 0.8927 - val_loss: 0.8300 - val_accuracy: 0.8096 - lr: 9.9000e-04
# Epoch 27/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.8938
# Epoch 00027: val_loss improved from 0.82997 to 0.77892, saving model to ./save/model/model_27.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5346 - accuracy: 0.8938 - val_loss: 0.7789 - val_accuracy: 0.8322 - lr: 9.9000e-04
# Epoch 28/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5263 - accuracy: 0.8968
# Epoch 00028: val_loss did not improve from 0.77892
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5263 - accuracy: 0.8968 - val_loss: 0.8827 - val_accuracy: 0.8099 - lr: 9.9000e-04
# Epoch 29/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5281 - accuracy: 0.8969
# Epoch 00029: val_loss did not improve from 0.77892
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5279 - accuracy: 0.8970 - val_loss: 1.0477 - val_accuracy: 0.7903 - lr: 9.9000e-04
# Epoch 30/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5210 - accuracy: 0.8991
# Epoch 00030: val_loss did not improve from 0.77892
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.5210 - accuracy: 0.8991 - val_loss: 1.0861 - val_accuracy: 0.7839 - lr: 9.9000e-04
# Epoch 31/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5131 - accuracy: 0.9015
# Epoch 00031: val_loss did not improve from 0.77892
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5135 - accuracy: 0.9015 - val_loss: 0.7814 - val_accuracy: 0.8334 - lr: 9.9000e-04
# Epoch 32/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5110 - accuracy: 0.9043
# Epoch 00032: val_loss did not improve from 0.77892
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5110 - accuracy: 0.9043 - val_loss: 1.2024 - val_accuracy: 0.7745 - lr: 9.9000e-04
# Epoch 33/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.9041
# Epoch 00033: val_loss improved from 0.77892 to 0.74171, saving model to ./save/model/model_33.h5
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5125 - accuracy: 0.9041 - val_loss: 0.7417 - val_accuracy: 0.8477 - lr: 9.9000e-04
# Epoch 34/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5045 - accuracy: 0.9044
# Epoch 00034: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5044 - accuracy: 0.9044 - val_loss: 0.7501 - val_accuracy: 0.8478 - lr: 9.9000e-04
# Epoch 35/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.9062
# Epoch 00035: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4986 - accuracy: 0.9062 - val_loss: 0.9728 - val_accuracy: 0.8009 - lr: 9.9000e-04
# Epoch 36/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4946 - accuracy: 0.9101
# Epoch 00036: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4946 - accuracy: 0.9101 - val_loss: 0.7666 - val_accuracy: 0.8443 - lr: 9.9000e-04
# Epoch 37/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.9084
# Epoch 00037: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5001 - accuracy: 0.9084 - val_loss: 0.7637 - val_accuracy: 0.8417 - lr: 9.9000e-04
# Epoch 38/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4925 - accuracy: 0.9103
# Epoch 00038: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4925 - accuracy: 0.9103 - val_loss: 1.0642 - val_accuracy: 0.7884 - lr: 9.9000e-04
# Epoch 39/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4858 - accuracy: 0.9145
# Epoch 00039: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4857 - accuracy: 0.9145 - val_loss: 1.0475 - val_accuracy: 0.7950 - lr: 9.9000e-04
# Epoch 40/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.9119
# Epoch 00040: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4887 - accuracy: 0.9119 - val_loss: 0.9776 - val_accuracy: 0.7929 - lr: 9.9000e-04
# Epoch 41/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4844 - accuracy: 0.9143
# Epoch 00041: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4846 - accuracy: 0.9142 - val_loss: 1.2328 - val_accuracy: 0.7707 - lr: 9.9000e-04
# Epoch 42/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4798 - accuracy: 0.9154
# Epoch 00042: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4798 - accuracy: 0.9154 - val_loss: 0.7533 - val_accuracy: 0.8424 - lr: 9.9000e-04
# Epoch 43/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4734 - accuracy: 0.9173
# Epoch 00043: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4735 - accuracy: 0.9173 - val_loss: 0.8001 - val_accuracy: 0.8403 - lr: 9.9000e-04
# Epoch 44/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4741 - accuracy: 0.9182
# Epoch 00044: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4742 - accuracy: 0.9181 - val_loss: 1.1657 - val_accuracy: 0.7747 - lr: 9.9000e-04
# Epoch 45/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4702 - accuracy: 0.9180
# Epoch 00045: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4701 - accuracy: 0.9180 - val_loss: 0.9118 - val_accuracy: 0.8156 - lr: 9.9000e-04
# Epoch 46/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4739 - accuracy: 0.9176
# Epoch 00046: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4738 - accuracy: 0.9176 - val_loss: 0.9622 - val_accuracy: 0.7963 - lr: 9.9000e-04
# Epoch 47/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4681 - accuracy: 0.9179
# Epoch 00047: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4684 - accuracy: 0.9179 - val_loss: 1.0055 - val_accuracy: 0.7939 - lr: 9.9000e-04
# Epoch 48/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4646 - accuracy: 0.9195
# Epoch 00048: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4646 - accuracy: 0.9195 - val_loss: 1.0694 - val_accuracy: 0.8035 - lr: 9.9000e-04
# Epoch 49/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.9203
# Epoch 00049: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4641 - accuracy: 0.9203 - val_loss: 0.8069 - val_accuracy: 0.8495 - lr: 9.9000e-04
# Epoch 50/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4632 - accuracy: 0.9202
# Epoch 00050: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4632 - accuracy: 0.9202 - val_loss: 0.8402 - val_accuracy: 0.8311 - lr: 9.9000e-04
# Epoch 51/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4598 - accuracy: 0.9223
# Epoch 00051: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 30ms/step - loss: 0.4597 - accuracy: 0.9222 - val_loss: 0.8885 - val_accuracy: 0.8183 - lr: 9.9000e-04
# Epoch 52/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.9227
# Epoch 00052: val_loss did not improve from 0.74171
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4615 - accuracy: 0.9227 - val_loss: 0.8630 - val_accuracy: 0.8362 - lr: 9.9000e-04
# Epoch 53/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.9218
# Epoch 00053: val_loss improved from 0.74171 to 0.71917, saving model to ./save/model/model_53.h5
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4622 - accuracy: 0.9218 - val_loss: 0.7192 - val_accuracy: 0.8545 - lr: 9.9000e-04
# Epoch 54/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4557 - accuracy: 0.9231
# Epoch 00054: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4559 - accuracy: 0.9230 - val_loss: 0.8295 - val_accuracy: 0.8428 - lr: 9.9000e-04
# Epoch 55/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.9222
# Epoch 00055: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4545 - accuracy: 0.9222 - val_loss: 1.1533 - val_accuracy: 0.7715 - lr: 9.9000e-04
# Epoch 56/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4564 - accuracy: 0.9228
# Epoch 00056: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4565 - accuracy: 0.9228 - val_loss: 0.8602 - val_accuracy: 0.8334 - lr: 9.9000e-04
# Epoch 57/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4511 - accuracy: 0.9243
# Epoch 00057: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.4513 - accuracy: 0.9242 - val_loss: 0.9012 - val_accuracy: 0.8280 - lr: 9.9000e-04
# Epoch 58/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4489 - accuracy: 0.9264
# Epoch 00058: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4489 - accuracy: 0.9264 - val_loss: 0.8833 - val_accuracy: 0.8298 - lr: 9.9000e-04
# Epoch 59/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4484 - accuracy: 0.9268
# Epoch 00059: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4484 - accuracy: 0.9268 - val_loss: 0.7897 - val_accuracy: 0.8510 - lr: 9.9000e-04
# Epoch 60/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.9252
# Epoch 00060: val_loss did not improve from 0.71917
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4512 - accuracy: 0.9252 - val_loss: 0.7250 - val_accuracy: 0.8435 - lr: 9.9000e-04
# 313/313 [==============================] - 5s 15ms/step - loss: 0.7250 - accuracy: 0.8435
# Test loss:      0.725042998790741
# Test accuracy:  0.843500018119812
